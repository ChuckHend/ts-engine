# %%
import monitor

# %%
monitor.save_stocks(saveDir='../data/30_second',interval="30",period='2d')
# Out:
# ACN complete
# ATVI complete
# ADBE complete
# AMD complete
# AKAM complete
# ADS complete
# GOOGL complete
# GOOG complete
# APH complete
# APC complete
# ADI complete
# ANDV complete
# ANSS complete
# APA complete
# AAPL complete
# AMAT complete
# ADSK complete
# ADP complete
# BHGE complete
# AVGO complete
# CA complete
# COG complete
# CDNS complete
# CVX complete
# XEC complete
# CSCO complete
# CTXS complete
# CTSH complete
# CXO complete
# COP complete
# GLW complete
# DVN complete
# DXC complete
# EBAY complete
# EA complete
# EOG complete
# EQT complete
# XOM complete
# FFIV complete
# FB complete
# FIS complete
# FISV complete
# FLIR complete
# IT complete
# GPN complete
# HAL complete
# HRS complete
# HP complete
# HES complete
# HPE complete
# HPQ complete
# INTC complete
# IBM complete
# INTU complete
# IPGP complete
# JNPR complete
# KMI complete
# KLAC complete
# LRCX complete
# MRO complete
# MPC complete
# MA complete
# MCHP complete
# MU complete
# MSFT complete
# ...
